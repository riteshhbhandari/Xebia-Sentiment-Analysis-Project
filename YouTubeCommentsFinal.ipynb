ip install vaderSentiment
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.2 MB/s eta 0:00:00
# ...

# %%
df
# Out:
#                    author          published_at            updated_at  \
# 0             @lexfridman  2022-02-26T17:18:44Z  2022-02-26T17:18:44Z
# 1         @bhavanimbm9605  2024-06-26T13:36:35Z  2024-06-26T13:36:35Z
# 2                @cpgm100  2024-06-19T20:33:44Z  2024-06-19T20:33:44Z
# 3        @Cody_theBoi2010  2024-06-17T22:57:58Z  2024-06-17T22:57:58Z
# 4               @psycleen  2024-06-16T23:01:48Z  2024-06-16T23:01:48Z
# ..                    ...                   ...                   ...
# 95             @razen4758  2023-09-03T10:45:05Z  2023-09-03T10:45:05Z
# 96        @andorandor5462  2023-09-01T18:24:05Z  2023-09-01T18:24:05Z
# 97         @brianwood6655  2023-08-30T08:18:09Z  2023-08-30T08:18:09Z
# 98      @shashwatsingh276  2023-08-24T14:11:34Z  2023-08-24T14:11:34Z
# 99  @guillermopadilla5840  2023-08-23T05:59:37Z  2023-08-23T05:59:37Z
#
#     like_count                                               text
# ...

# %%
# # STORING THE SENTIMENTS IN ORIGINAL

# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# # Initialize VADER sentiment analyzer
# analyzer = SentimentIntensityAnalyzer()

# # Analyze sentiment of each comment and store in DataFrame
# sentiments = df['text'].apply(lambda x: analyzer.polarity_scores(x))

# # Convert sentiment analysis results to DataFrame and merge with original DataFrame
# sentiment_df = pd.DataFrame(sentiments.tolist())
# sentiment_df = sentiment_df.drop(columns=df.columns.intersection(sentiment_df.columns))
# df = pd.concat([df, sentiment_df], axis=1)
# print(df.head(10))

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Analyze sentiment of each comment and store in DataFrame
sentiments = df['text'].apply(lambda x: analyzer.polarity_scores(x))
# Convert sentiment analysis results to DataFrame and merge with original DataFrame
sentiment_df = pd.DataFrame(sentiments.tolist())
sentiment_df
# Out:
#       neg    neu    pos  compound
# 0   0.000  0.929  0.071    0.8504
# 1   0.000  0.966  0.034    0.4404
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  1.000  0.000    0.0000
# 4   0.000  1.000  0.000    0.0000
# ..    ...    ...    ...       ...
# 95  0.366  0.634  0.000   -0.6825
# 96  0.198  0.689  0.113   -0.2700
# 97  0.325  0.675  0.000   -0.8793
# 98  0.000  1.000  0.000    0.0000
# 99  0.000  0.219  0.781    0.9873
#
# [100 rows x 4 columns]

# %%
sent_df=['author', 'published_at', 'updated_at', 'like_count','text']
new_df = df[sent_df].copy();
sentiment_df['sentiment'] = sentiment_df['compound'].apply(lambda x: 'positive' if x > 0 else ('negative' if x < 0 else 'neutral'))
new_df=pd.concat([new_df,sentiment_df], axis=1)
print(new_df.head(10))

new_df=new_df.drop(['author', 'published_at', 'updated_at', 'like_count'],axis=1)
new_df
# Out:
#                  author          published_at            updated_at  \
# 0           @lexfridman  2022-02-26T17:18:44Z  2022-02-26T17:18:44Z
# 1       @bhavanimbm9605  2024-06-26T13:36:35Z  2024-06-26T13:36:35Z
# 2              @cpgm100  2024-06-19T20:33:44Z  2024-06-19T20:33:44Z
# 3      @Cody_theBoi2010  2024-06-17T22:57:58Z  2024-06-17T22:57:58Z
# 4             @psycleen  2024-06-16T23:01:48Z  2024-06-16T23:01:48Z
# 5  @lakshaydhankhar9077  2024-06-14T13:27:15Z  2024-06-14T17:14:03Z
# 6          @ciCCapROSTi  2024-06-11T11:41:31Z  2024-06-11T11:41:31Z
# 7         @serifeak9757  2024-06-09T16:31:44Z  2024-06-09T16:31:44Z
# 8      @user-jb4me9hn4m  2024-06-05T04:13:59Z  2024-06-05T04:13:59Z
# 9     @TheTomorrowDream  2024-06-03T04:30:57Z  2024-06-03T04:30:57Z
#
#    like_count                                               text    neg  \
# 0        2264  Here are the timestamps. Please check out our ...  0.000
# 1           0  Its easy ti soeak extenoire about analyis...u ...  0.000
# ...

# %%
data2=new_df.drop(['pos','neg','neu','compound'],axis=1)
data2
# Out:
#                                                  text sentiment
# 0   Here are the timestamps. Please check out our ...  positive
# 1   Its easy ti soeak extenoire about analyis...u ...  positive
# 2   interviewer asks a question<br>answer: let&#39...   neutral
# 3          Why tf is this video in a wildcat playlist   neutral
# 4                                                 fbi   neutral
# ..                                                ...       ...
# 95         this guy is so illegal. . young phony guy.  negative
# 96  Half way into the video with few skips I must ...  negative
# 97  Mark Zuckerberg has been TORTURING me for more...  negative
# 98  <a href="https://www.youtube.com/watch?v=5zOHS...   neutral
# 99                            Love you people ❤❤❤❤❤❤🎉  positive
#
# [100 rows x 2 columns]

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
# Out:
#   File "<ipython-input-18-f4186066cc2e>", line 1
#     pip install nltk
#         ^
# SyntaxError: invalid syntax

# %%
import nltk
nltk.download('stopwords')
stop_words = stopwords.words('english')
print(stop_words)

porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()
snowball_stemer = SnowballStemmer(language="english")
lzr = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e242efef007e> in <cell line: 3>()
#       1 import nltk
#       2 nltk.download('stopwords')
# ----> 3 stop_words = stopwords.words('english')
#       4 print(stop_words)
#       5
#
# NameError: name 'stopwords' is not defined

# %%
# VISULATISATION
import matplotlib.pyplot as plt

# Assuming sentiment_df already contains 'compound' and 'sentiment' columns

# Count of each sentiment category
sentiment_counts = sentiment_df['sentiment'].value_counts()

# Bar plot
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['green', 'red', 'blue'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# Pie chart
plt.figure(figsize=(8, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=['green', 'red', 'blue'])
plt.title('Sentiment Distribution')
plt.axis('equal')
plt.show()

# %%
# Histogram of compound scores
plt.figure(figsize=(8, 6))
plt.hist(sentiment_df['compound'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Compound Sentiment Scores')
plt.xlabel('Compound Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box plot of compound scores
plt.figure(figsize=(8, 6))
plt.boxplot(sentiment_df['compound'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Box Plot of Compound Sentiment Scores')
plt.xlabel('Compound Score')
plt.yticks([])
plt.grid(True)
plt.show()

# %%
print(df[df['like_count'] > 200]['text'])
# Out:
# 0    Here are the timestamps. Please check out our ...
# Name: text, dtype: object

# %%
# Scatter plot of compound vs. like count
plt.figure(figsize=(8, 6))
plt.scatter(new_df['like_count'], sentiment_df['compound'], color='purple', alpha=0.5)
plt.title('Compound Sentiment Score vs. Like Count')
plt.xlabel('Like Count')
plt.ylabel('Compound Score')
plt.grid(True)
plt.show()

# %%
from wordcloud import WordCloud

# Combine all comments into a single text for word cloud
all_comments = ' '.join(df['text'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_comments)

# Plot word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Comments')
plt.axis('off')
plt.show()
